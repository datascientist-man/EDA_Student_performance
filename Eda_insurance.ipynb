# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"D:\Machine_learning\insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
df.tail(10)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1328   23  female  24.225         2     no  northeast  22395.74424
# 1329   52    male  38.600         2     no  southwest  10325.20600
# 1330   57  female  25.740         2     no  southeast  12629.16560
# 1331   23  female  33.400         0     no  southwest  10795.93733
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Length: 1338, dtype: bool

# %%
#df.drop_duplicates(keep='first',inplace=True)

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.countplot(data=df,x='sex',palette='rocket')
# Out:
# C:\Users\manis\AppData\Local\Temp\ipykernel_17428\2147522671.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='sex',palette='rocket')
# <Axes: xlabel='sex', ylabel='count'>

# %%
plt.hist(df.age, bins=10,color='yellow',edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(axis='y')

# %%
avg_bmi_age=df.groupby('age')['bmi'].mean()
plt.plot(avg_bmi_age.index,avg_bmi_age.values)
plt.title('Average BMI Trend by Age')
plt.xlabel('Age')
plt.ylabel('Average BMI')
# Out:
# Text(0, 0.5, 'Average BMI')

# %%
sex_wise_bmi=df.groupby('sex')['bmi'].mean()
sex_wise_bmi
# Out:
# sex
# female    30.377749
# male      30.943129
# Name: bmi, dtype: float64

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
plt.bar(sex_wise_bmi.index,sex_wise_bmi.values,color=['pink','skyblue'])
plt.ylabel('Mean BMI')
# Out:
# Text(0, 0.5, 'Mean BMI')

# %%
sns.boxplot(data=df,x='bmi')
plt.title('BMI Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('BMI Index')
plt.show()

# %%
df.isnull().any()
# Out:
# age         False
# sex         False
# bmi         False
# children    False
# smoker      False
# region      False
# charges     False
# dtype: bool

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, root_mean_squared_error

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder, LabelEncoder

# %% [markdown]
# ## Multiple Linear Regression

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
x1 = df[['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']]

# %%
x = df.drop('charges',axis=1)
y = df.charges

# %%
x1 = pd.get_dummies(x)
x1
# Out:
#       age     bmi  children  sex_female  sex_male  smoker_no  smoker_yes  \
# 0      19  27.900         0        True     False      False        True
# 1      18  33.770         1       False      True       True       False
# 2      28  33.000         3       False      True       True       False
# 3      33  22.705         0       False      True       True       False
# 4      32  28.880         0       False      True       True       False
# ...   ...     ...       ...         ...       ...        ...         ...
# 1333   50  30.970         3       False      True       True       False
# 1334   18  31.920         0        True     False       True       False
# 1335   18  36.850         0        True     False       True       False
# 1336   21  25.800         0        True     False       True       False
# 1337   61  29.070         0        True     False      False        True
#
#       region_northeast  region_northwest  region_southeast  region_southwest
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x1,y, train_size=0.80, random_state=42)

# %%
x_train
# Out:
#       age     bmi  children  sex_female  sex_male  smoker_no  smoker_yes  \
# 560    46  19.950         2        True     False       True       False
# 1285   47  24.320         0        True     False       True       False
# 1142   52  24.860         0        True     False       True       False
# 969    39  34.320         5        True     False       True       False
# 486    54  21.470         3        True     False       True       False
# ...   ...     ...       ...         ...       ...        ...         ...
# 1095   18  31.350         4        True     False       True       False
# 1130   39  23.870         5        True     False       True       False
# 1294   58  25.175         0       False      True       True       False
# 860    37  47.600         2        True     False      False        True
# 1126   55  29.900         0       False      True       True       False
#
#       region_northeast  region_northwest  region_southeast  region_southwest
# ...

# %%
x_test
# Out:
#       age     bmi  children  sex_female  sex_male  smoker_no  smoker_yes  \
# 764    45  25.175         2        True     False       True       False
# 887    36  30.020         0        True     False       True       False
# 890    64  26.885         0        True     False      False        True
# 1293   46  25.745         3       False      True       True       False
# 259    19  31.920         0       False      True      False        True
# ...   ...     ...       ...         ...       ...        ...         ...
# 109    63  35.090         0       False      True      False        True
# 575    58  27.170         0        True     False       True       False
# 535    38  28.025         1       False      True       True       False
# 543    54  47.410         0        True     False      False        True
# 846    51  34.200         1        True     False       True       False
#
#       region_northeast  region_northwest  region_southeast  region_southwest
# ...

# %%
y_train
# Out:
# 560      9193.83850
# 1285     8534.67180
# 1142    27117.99378
# 969      8596.82780
# 486     12475.35130
#            ...
# 1095     4561.18850
# 1130     8582.30230
# 1294    11931.12525
# 860     46113.51100
# 1126    10214.63600
# Name: charges, Length: 1070, dtype: float64

# %%
y_test
# Out:
# 764      9095.06825
# 887      5272.17580
# 890     29330.98315
# 1293     9301.89355
# 259     33750.29180
#            ...
# 109     47055.53210
# 575     12222.89830
# 535      6067.12675
# 543     63770.42801
# 846      9872.70100
# Name: charges, Length: 268, dtype: float64

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)  #fit-> apply logic, transform -> to transform/change, fit_transform -> change then apply
# Out:
# LinearRegression()

# %%
ypredict = lr.predict(x_test)

# %%
r2 = r2_score(y_test, ypredict)
r2*100
# Out:
# 78.35929767120723

# %%
mae = mean_absolute_error(y_test,ypredict)
mae
# Out:
# 4181.194473753645

# %%
mse = mean_squared_error(y_test, ypredict)
mse
# Out:
# 33596915.85136147

# %%
rmse = root_mean_squared_error(y_test,ypredict)
rmse
# Out:
# 5796.2846592762735

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
mape = mean_absolute_percentage_error(y_test,ypredict)
mape
# Out:
# 0.4688825597914671

# %% [markdown]
# ## Simple Linear Regrassion

# %%
#x = df[["age"]]
#y = df["charges"]

# %%
#x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.20, random_state=42)

# %%
#slr = LinearRegression()

# %%
#slr.fit(x_train,y_train)

# %%
#y_pred = slr.predict(x_test)

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import Lasso, Ridge, ElasticNet

# %%
l1 = Lasso()

# %%
l1.fit(x_train,y_train)
# Out:
# Lasso()

# %%
y_pred_l1 = l1.predict(x_test)

# %%
r2_l1 = r2_score(y_test,y_pred_l1)
r2_l1*100
# Out:
# 78.35348987579266

# %%
mae_l1 = mean_absolute_error(y_test,y_pred_l1)
mae_l1
# Out:
# 4182.297003584162

# %%
mse_l1 = mean_squared_error(y_test,y_pred_l1)
mse_l1
# Out:
# 33605932.380070224

# %%
rmse_l1 = root_mean_squared_error(y_test,y_pred_l1)
rmse_l1
# Out:
# 5797.062392287168

# %%
mape_l1 = mean_absolute_percentage_error(y_test,y_pred_l1)
mape_l1
# Out:
# 0.46921872725413544

# %%
l2 = Ridge()

# %%
l2.fit(x_train,y_train)
# Out:
# Ridge()

# %%
y_pred_l2 = l2.predict(x_test)

# %%
r2_l2 = r2_score(y_test,y_pred_l2)
r2_l2*100
# Out:
# 78.34446266673822

# %%
mae_l2 = mean_absolute_error(y_test,y_pred_l2)
mae_l2
# Out:
# 4187.302782980901

# %%
mse_l2 = mean_squared_error(y_test,y_pred_l2)
mse_l2
# Out:
# 33619947.00761634

# %%
rmse_l2 = root_mean_squared_error(y_test,y_pred_l2)
rmse_l2
# Out:
# 5798.271036060348

# %%
mape_l2 = mean_absolute_percentage_error(y_test,y_pred_l2)
mape_l2
# Out:
# 0.4701154103689938

# %%
l3 = ElasticNet()

# %%
l3.fit(x_train,y_train)
# Out:
# ElasticNet()

# %%
y_pred_l3 = l3.predict(x_test)

# %%
r3_l2 = r2_score(y_test,y_pred_l3)
r3_l2*100
# Out:
# 54.263426838653906

# %%
mae_l3 = mean_absolute_error(y_test,y_pred_l3)
mae_l3
# Out:
# 6382.3424635146985

# %%
mse_l3 = mean_squared_error(y_test,y_pred_l3)
mse_l3
# Out:
# 71005449.66079675

# %%
rmse_l3 = root_mean_squared_error(y_test,y_pred_l3)
rmse_l3
# Out:
# 8426.473144845164

# %%
mape_l3 = mean_absolute_percentage_error(y_test,y_pred_l3)
mape_l3
# Out:
# 0.8902787677528596
